# %% [markdown]
# <a href="https://colab.research.google.com/github/20241984/Ejercicios/blob/main/Cargar_filtrar_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

import pandas as pd
# Nombren el Datafrme como bike_df
filename ='/content/sample_data/RailsToTrails_National Count Data_week.xlsx'
bike_df= pd.read_excel(filename)
bike_df
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                      167679
# 1     Week 2 2020-01-06                       82340
# 2     Week 3 2020-01-13                       62315
# 3     Week 4 2020-01-20                       75801
# 4     Week 5 2020-01-27                       75841
# 5     Week 6 2020-02-03                       79780
# 6     Week 7 2020-02-10                       65732
# 7     Week 8 2020-02-17                       69492
# 8     Week 9 2020-02-24                       85688
# 9    Week 10 2020-03-02                       84512
# 10   Week 11 2020-03-09                      107995
# 11   Week 12 2020-03-16                      125440
# 12   Week 13 2020-03-23                      136330
# 13   Week 14 2020-03-30                      118784
# 14   Week 15 2020-04-06                      132033
# 15   Week 16 2020-04-13                      133267
# 16   Week 17 2020-04-20                      165777
# ...

# %%
#Práctica de filtración
# 1 Solo seleccionen los datos después del 31 de julio de 2020.
filtro_fec = bike_df[bike_df["Week of"] > "2020-07-31"]
filtro_fec
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                      167679
# 44   Week 45 2020-11-02                      109766
# 45   Week 46 2020-11-09                       86824
# 46   Week 47 2020-11-16                       88122
# 47   Week 48 2020-11-23                       72380
# 48   Week 49 2020-11-30                       81871
# 49   Week 50 2020-12-07                       68364
# 50   Week 51 2020-12-14                       58063
# 51   Week 52 2020-12-21                       71890
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                       183546          NaN          0.094627    1.094627
# 44                      154502          NaN          0.410000  140.755790
# 45                      155805          NaN          0.790000  179.449231
# 46                       97835          NaN          0.110000  111.022219
# ...

# %%
# 2 Solo seleccionen los datos donde la columna “Change 2019-2020”
# es superior al 100 % (superior 1).
filtro_change = bike_df['Change 2019-2020']> 1
filtro_change.head()
bike_df.loc[filtro_change,:].head()
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 7     Week 8 2020-02-17                       69492
# 11   Week 12 2020-03-16                      125440
# 12   Week 13 2020-03-23                      136330
# 13   Week 14 2020-03-30                      118784
# 14   Week 15 2020-04-06                      132033
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 7                       149876          NaN          1.156737  215.673747
# 11                      367795          NaN          1.932039  293.203922
# 12                      372783          NaN          1.730000  273.441649
# 13                      280728          NaN          1.360000  236.334860
# 14                      419160          NaN          2.170000  317.466088
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 7          NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# ...

# %%
# 3¡Únanlos! ¿Hubo alguna semana en la segunda mitad del año
# (después del 31 de julio de 2020) en la que el cambio fuera superior al 100 %?
bike_df = bike_df[(bike_df["Week of"]>"2020-07-31")
              &
              (bike_df["Change 2019-2020"]>1)]
bike_df.shape
# esta parte no me resulto la deje con comentarios
# if cambios_mayores_a_100_julio.empty:
# print("No Hubo alguna semana en la segunda mitad del año (después del 31 de julio de 2020) en la que el cambio fuera superior al 100 %")
# else:
# print("si hubo")
# Out:
# (0, 10)
